# %% [markdown]
# ### 웹툰 이미지를 다운로드하여 로컬에 저장하기

# %%
import requests
import os

req_header_dict = {
    'referer' : 'https://comic.naver.com/webtoon/detail?titleId=748105&no=145&weekday=thu'
}
img_url_list = {
    'https://image-comic.pstatic.net/webtoon/748105/145/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_1.jpg',
    'https://image-comic.pstatic.net/webtoon/748105/145/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_2.jpg',
    'https://image-comic.pstatic.net/webtoon/748105/145/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_3.jpg'
}

for img_url in img_url_list:
    res = requests.get(img_url, headers=req_header_dict)
    print(res.status_code)
    if res.ok:
        # binary data 가져올때 .content 속성사용
        img_data = res.content

        # url에서 파일명만 추출하기
        file_name = os.path.basename(img_url)
        file_name = 'data/' + file_name

        # 서버에서 가져온 binary data를 file로 저장하기
        with open(file_name, 'wb') as file:
            print(f'Write to file {file_name} ({len(img_data):,}) bytes')
            file.write(img_data)
# Out:
# 200
# Write to file data/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_1.jpg (115,541) bytes
# 200
# Write to file data/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_2.jpg (117,154) bytes
# 200
# Write to file data/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_3.jpg (139,410) bytes

# %% [markdown]
# ### 웹툰의 특정회차의 모든 image 다운로드 하기
# * Attribute Selector를 사용하여 jpg 파일명들을 모두 추출하여 리스트에 저장하기
# * 리스트를 순회하면서 image 다운로드 하기

# %%
# !pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.10.0-py3-none-any.whl (97 kB)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.3.1-py3-none-any.whl (37 kB)
# Using legacy 'setup.py install' for bs4, since package 'wheel' is not installed.
# Installing collected packages: soupsieve, beautifulsoup4, bs4
#     Running setup.py install for bs4: started
#     Running setup.py install for bs4: finished with status 'done'
# Successfully installed beautifulsoup4-4.10.0 bs4-0.0.1 soupsieve-2.3.1
#
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <title>독립일기 :: 네이버 만화</title>
# <meta content="독립일기 - 시즌2 42화 시간제 캠핑" property="og:title"/>
# <meta content="https://shared-comic.pstatic.net/thumb/webtoon/748105/145/thumbnail_600x315_753eff7c-e34c-4cfd-95ab-c7e76f88ddee.jpg" property="og:image"/>
# <meta content="시즌2 42화 시간제 캠핑" property="og:description"/>
# <meta content="https://comic.naver.com/webtoon/detail?titleId=748105&amp;no=145&amp;weekday=thu" property="og:url"/>
# <meta content="article" property="og:type"/>
# <meta content="네이버 웹툰" property="og:article:author"/>
# <meta content="https://comic.naver.com" property="og:article:author:url"/>
# <link href="https://ssl.pstatic.net/static/comic/favicon/webtoon_favicon_32x32.ico" rel="shortcut icon" type="image/x-icon"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="IE=edge, chrome=1" http-equiv="X-UA-Compatible"/>
# <link href="/css/comic/comic_20220127144815.css" rel="stylesheet" style="text/css"/>
# <link href="/css/comic/view_20220127144815.css" rel="stylesheet" style="text/css"/>
# <script src="/aggregate/javascript/release/comic_detailscroll_20220127144815.js" type="text/javascript"></script>
# <style type="text/css">
# @media screen and (max-width:720px) {
#  .sc_plugin.ly_link{left:initial;right:0;}
# }
# </style>
# <script src="/aggregate/javascript/release/comic_gnb_20220127144815.js" type="text/javascript"></script>
# </head>
# <body onload="">
# <div class="end_page" id="wrap">
# <a class="blind" href="#content">본문 바로가기</a>
# <div id="header_wrap">
# <div id="header">
# <div id="gnb">
# <script type="text/javascript">
#         var gnb_option = {
#             gnb_service : "comic",
#             gnb_logout :  encodeURIComponent(window.location.href),
#             gnb_login :   encodeURIComponent(window.location.href),
#             gnb_template : "gnb_utf8",
#             gnb_brightness : 1,
#             gnb_item_hide_option: 0
#         };
#     </script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.gn/templates/gnb_utf8?20220127144815" type="text/javascript"></script>
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="Ntxt_naver" href="https://www.naver.com" onclick="nclk_v2(event,'STA.naverlogo')" title="NAVER">NAVER</a>
# <a class="Ntxt_comic" href="/index" onclick="nclk_v2(event,'STA.comic')" title="만화">만화</a>
# <em class="bar">|</em>
# <a class="Ntxt_novel" href="https://novel.naver.com" onclick="nclk_v2(event,'STA.novel')" title="웹소설">웹소설</a>
# </h1>
# <form action="/search" id="searchForm" method="get" name="search">
# <fieldset>
# <legend>검색</legend>
# <div class="snb_search_box">
# <div class="snb_search_box_sub">
# <!-- [D] 클릭시 label.ph 텍스트 삭제해주세요. -->
# <label class="ph" for="gnb.keyword">제목/작가로 검색할 수 있습니다.</label>
# <input class="snb_search_text" id="gnb.keyword" maxlength="18" name="keyword" title="검색어 입력" type="text" value=""/>
# <button alt="검색" class="btn_search" id="search_bar_button" onclick="nclk_v2(event,'STA.search')" title="검색" type="button"><span class="Nico_search">검색</span></button>
# </div>
# </div>
# </fieldset>
# </form>
# </div>
# <div id="author_layer" style="text-align:left; display:none;">
# <ul id="author_layer_inner"> </ul>
# </div>
# <div class="notice_info">
# <span class="blind">공지사항</span>
# <div class="rolling">
# <div class="notice_rolling">
# <li>
# <a href="https://comic.naver.com/webtoon/list.nhn?titleId=787465" onclick="nclk_v2(event,'STA.txt')" title="내 짝꿍은 로봇? &lt;철수와 영희 이야기&gt;">
# <span class="Nico_notice"></span>
# 										내 짝꿍은 로봇? &lt;철수와 영희 이야기&gt;
# 									</a>
# </li>
# </div>
# </div>
# </div>
# </div>
# <div id="menu">
# <ul class="menu">
# <!-- [D] 선택된 li에 current 클래스 추가 -->
# <li><a href="/index" onclick="nclk_v2(event,'LNB.home');"><span class="Ntxt_home">웹툰 홈</span></a></li>
# <li class="current"><a href="/webtoon/weekday" onclick="nclk_v2(event,'LNB.toon');"><span class="Ntxt_webtoon">웹툰</span></a></li>
# <li><a href="/genre/bestChallenge" onclick="nclk_v2(event,'LNB.best');"><span class="Ntxt_best_challenge">베스트 도전</span></a></li>
# <li><a href="/genre/challenge" onclick="nclk_v2(event,'LNB.chal');"><span class="Ntxt_challenge_comic">도전만화</span></a></li>
# <li><a href="/mypage/favorite" onclick="nclk_v2(event,'LNB.my');"><span class="Ntxt_mypage">마이페이지</span></a><span class="bar"></span></li>
# <li><a href="https://series.naver.com/comic/recommendList.series" onclick="nclk_v2(event,'LNB.char');" target="_blank"><span class="Ntxt_short_story">단행본 만화</span></a></li>
# <li class="genre_novel"><a href="https://series.naver.com/novel/recommendList.series" onclick="nclk_v2(event,'LNB.novel');" target="_blank"><span class="Ntxt_genre_novel">장르소설</span></a></li>
# </ul>
# <h2 class="blind">웹툰</h2>
# </div>
# <!-- //상단 메뉴 /webtoon/detail-->
# <div id="submenu">
# <!--서브메뉴-->
# <ul class="submenu">
# <!-- [D] 선택된 li에 on 클래스 추가 -->
# <li class="on"><a href="/webtoon/weekday" onclick="nclk_v2(event,'tab.weekday')"><span class="Ntxt_menu_date">요일별</span></a></li>
# <li><a href="/webtoon/genre" onclick="nclk_v2(event,'tab.genre')"><span class="Ntxt_menu_genre">장르별</span></a></li>
# <li><a href="/webtoon/creation" onclick="nclk_v2(event,'tab.creation')"><span class="Ntxt_menu_art">작품별</span></a></li>
# <li><a href="/webtoon/artist" onclick="nclk_v2(event,'tab.artist')"><span class="Ntxt_menu_author">작가별</span></a></li>
# <li><a href="/webtoon/period" onclick="nclk_v2(event,'tab.period')"><span class="Ntxt_menu_year">연도별</span></a></li>
# <li><a href="/webtoon/theme" onclick="nclk_v2(event,'tab.theme')"><span class="Ntxt_menu_theme">테마웹툰</span></a></li>
# <li><a href="/webtoon/finish" onclick="nclk_v2(event,'tab.finish')"><span class="Ntxt_menu_end">완결웹툰</span></a></li>
# </ul>
# <!--//서브메뉴-->
# </div>
# </div>
# <!-- 상단 영역(메인에만 나감.) -->
# <!-- //상단 영역 -->
# <div class="" id="container">
# <div class="webtoon" id="content">
# <ul class="category_tab">
# <li class=""><a href="/webtoon/weekday" onclick="nclk_v2(event,'dna.all')">요일전체</a></li>
# <li class=""><a href="/webtoon/weekdayList?week=mon" onclick="nclk_v2(event,'dna.monday')">월요웹툰</a></li>
# <li class=""><a href="/webtoon/weekdayList?week=tue" onclick="nclk_v2(event,'dna.tuesday')">화요웹툰</a></li>
# <li class=""><a href="/webtoon/weekdayList?week=wed" onclick="nclk_v2(event,'dna.wednesday')">수요웹툰</a></li>
# <li class="on"><a href="/webtoon/weekdayList?week=thu" onclick="nclk_v2(event,'dna.thursday')">목요웹툰</a></li>
# <li class=""><a href="/webtoon/weekdayList?week=fri" onclick="nclk_v2(event,'dna.friday')">금요웹툰</a></li>
# <li class=""><a href="/webtoon/weekdayList?week=sat" onclick="nclk_v2(event,'dna.saturday')">토요웹툰</a></li>
# <li class=""><a href="/webtoon/weekdayList?week=sun" onclick="nclk_v2(event,'dna.sunday')">일요웹툰</a></li>
# <li class=""><a href="/webtoon/weekdayList?week=dailyplus" onclick="nclk_v2(event,'dna.daily')">매일+웹툰</a></li>
# </ul>
# <!-- body -->
# <script type="text/javascript">
#     jQuery.noConflict()
#     function loadImageEvent(element){
#         if ( element ) {
#             if( element.width && element.width > 900 ) {
#                 element.width = 900;
#             }
#         }
#     }
#     window.__state__ = {
#         staticDomain: ''
#     }
# </script>
# <!-- //tab -->
# <div class="section_cont wide" id="sectionContWide">
# <div class="comicinfo">
# <div class="thumb">
# <a href="/webtoon/list?titleId=748105&amp;no=145&amp;weekday=thu" onclick="javascript:nclk_v2(event,'inf.img');">
# <img alt="독립일기" height="120" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/748105/thumbnail/thumbnail_IMAG04_2b479f04-a16b-4fa2-9a05-bc60cd84022c.jpg" title="독립일기" width="218"/>
# <span class="mask"></span>
# </a>
# </div>
# <div class="detail">
# <h2><span class="title">독립일기</span> <span class="ico_cut">컷툰</span> <span class="wrt_nm">							 자까							 						 </span>
# </h2>
# <p class="txt">처음으로 나만의 집이 생긴다면? <br/>자까 작가의 나혼자 사는 이야기</p>
# <p class="detail_info"><span class="genre">에피소드, 일상</span><span class="age">전체연령가</span></p>
# <ul class="btn_group">
# <li>
# <a class="book_maker" onclick="return actionRunner.addFavoriteWebtoon('748105', 'inf', event);" title="관심웹툰">
# <span>관심웹툰</span>
# </a>
# </li>
# <li><a class="first" href="#" onclick="nclk_v2(event,'inf.first');return checkServiceCode('subTitle','S00','1');" title="첫회보기"><span>첫회보기</span></a></li>
# <li><a class="lst" href="/webtoon/list?titleId=748105&amp;weekday=thu" onclick="nclk_v2(event,'inf.list')" title="목록보기"><span>목록보기</span></a></li>
# <li><a class="other" href="#" id="other_content" onclick="nclk_v2(event,'inf.artist');return actionRunner.artistForArtistTitle(this);" title="작가의 다른 작품"><span>작가의 다른 작품</span></a></li>
# </ul>
# </div>
# </div>
# <div class="tit_area">
# <div class="view">
# <h3>시즌2 42화 시간제 캠핑</h3>
# <div class="btn_area">
# <!-- 유료화구간 -->
# <span class="pre">
# <a href="#" onclick="nclk_v2(event,'bdt.prev');return checkServiceCode('subTitle','S00','144');">이전화</a>
# </span>
# </div>
# </div>
# <div class="vote_lst">
# <dl class="lt">
# <dt><img alt="회별별점" height="11" src="https://ssl.pstatic.net/static/comic/images/migration/detail/txt_point_all.gif" width="39"/></dt>
# <dd class="total">
# <div class="rating_type4" id="topTotalStarPoint">
# <span class="star"><em style="width:99%">평점</em></span>
# <span id="topPointTotalNumber"><strong>9.98</strong></span>
# <span class="pointTotalPerson">(참여 <em>13384</em>)</span>
# </div>
# </dd>
# <dt id="topStarLabel"><img alt="별점주기" class="starscore_guide_txt" height="11" src="https://ssl.pstatic.net/static/comic/images/migration/detail/txt_point_click.gif" width="38"/></dt>
# <dd id="topStarSelectbox">
# <div class="pointSelect fl">
# <a class="default" href="#" id="starScoreMenu_1" onclick="nclk_v2(event,'bdt.star','','11')"><span class="star_type4"><span class="mask" id="topTargetMask" style="width:100%"><img alt="점수선택" class="starscore_star_pic" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/ico_star_n.gif" width="60"/></span></span></a>
# <ul id="pointSelectOption" style="display:none">
# <li><a href="#" id="topStar10Select" onclick="nclk_v2(event,'bdt.star','','10')" title="10점"><span class="star_type4"><span class="mask" style="width:100%"><img alt="10점" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/ico_star_n.gif" width="60"/>10점</span></span></a></li>
# <li><a href="#" id="topStar9Select" onclick="nclk_v2(event,'bdt.star','','9')" title="9점"><span class="star_type4"><span class="mask" style="width:90%"><img alt="9점" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/ico_star_n.gif" width="60"/>9점</span></span></a></li>
# <li><a href="#" id="topStar8Select" onclick="nclk_v2(event,'bdt.star','','8')" title="8점"><span class="star_type4"><span class="mask" style="width:80%"><img alt="8점" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/ico_star_n.gif" width="60"/>8점</span></span></a></li>
# <li><a href="#" id="topStar7Select" onclick="nclk_v2(event,'bdt.star','','7')" title="7점"><span class="star_type4"><span class="mask" style="width:70%"><img alt="7점" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/ico_star_n.gif" width="60"/>7점</span></span></a></li>
# <li><a href="#" id="topStar6Select" onclick="nclk_v2(event,'bdt.star','','6')" title="6점"><span class="star_type4"><span class="mask" style="width:60%"><img alt="6점" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/ico_star_n.gif" width="60"/>6점</span></span></a></li>
# <li><a href="#" id="topStar5Select" onclick="nclk_v2(event,'bdt.star','','5')" title="5점"><span class="star_type4"><span class="mask" style="width:50%"><img alt="5점" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/ico_star_n.gif" width="60"/>5점</span></span></a></li>
# <li><a href="#" id="topStar4Select" onclick="nclk_v2(event,'bdt.star','','4')" title="4점"><span class="star_type4"><span class="mask" style="width:40%"><img alt="4점" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/ico_star_n.gif" width="60"/>4점</span></span></a></li>
# <li><a href="#" id="topStar3Select" onclick="nclk_v2(event,'bdt.star','','3')" title="3점"><span class="star_type4"><span class="mask" style="width:30%"><img alt="3점" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/ico_star_n.gif" width="60"/>3점</span></span></a></li>
# <li><a href="#" id="topStar2Select" onclick="nclk_v2(event,'bdt.star','','2')" title="2점"><span class="star_type4"><span class="mask" style="width:20%"><img alt="2점" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/ico_star_n.gif" width="60"/>2점</span></span></a></li>
# <li><a href="#" id="topStar1Select" onclick="nclk_v2(event,'bdt.star','','1')" title="1점"><span class="star_type4"><span class="mask" style="width:10%"><img alt="1점" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/ico_star_n.gif" width="60"/>1점</span></span></a></li>
# </ul>
# </div>
# <a class="btn_bx fl" href="#" id="topStarScoreSubmitButton" onclick="nclk_v2(event,'bdt.starok');"><span>확인</span></a>
# </dd>
# <dd class="txt" id="topStarText" style="display:none;"><span>참여하셨습니다.</span></dd>
# </dl>
# <dl class="rt">
# <dt>등록일</dt>
# <dd class="date">2022.01.26</dd>
# <dt class="blind">주소복사</dt>
# <dd class="add">
# <a class="btn_bx" href="#" id="copyUrlActionMenu" onclick="nclk_v2(event,'bdt.url')"><span>주소복사</span></a>
# <!-- [D] layer 주소복사 -->
# <div id="layerAddressBox" style="display:none;top:22px;right:11px;z-index:500;">
# <div class="layerAddressBg">
# <div class="layerAddress">
# <address id="thisUrl">https://comic.naver.com/webtoon/detail?titleId=748105&amp;no=145</address>
# 										클립보드에 주소가 복사되었습니다.<br/>
# <span class="key">[ctrl+v]</span>를 이용하여 주소를 붙여넣기 하실 수 있습니다.
# 										<a href="#"><img alt="닫기" height="14" src="https://ssl.pstatic.net/static/comic/images/migration/common/btn_close_layer.gif" title="닫기" width="15"/></a>
# </div>
# </div>
# </div>
# <!-- //layer 주소복사 -->
# </dd>
# <dt class="blind">리모컨 컨트롤</dt>
# <dd class="remote_area on" id="ddRemoteConOnOff"><a class="btn_bx btn_remote" href="#" id="btnRemoteConOnOff">리모컨 <em>ON</em></a>
# <!-- 리모컨 -->
# <div class="_remoteControl remote" id="comicRemocon" style="display: block; position:fixed;top:481.5px;left:1813px;z-index:1000;cursor:move">
# <div class="h_area">
# <strong>리모콘</strong>
# </div>
# <div class="remote_cont">
# <a class="tit" href="#">독립일기</a>
# <div class="btn_area">
# <a class="btn_prev_end" href="#" onclick="nclk_v2(event,'con.first');return checkServiceCode('remoteCtr','S00','1');" title="맨 처음">처음</a>
# <a class="btn_prev" href="#" onclick="nclk_v2(event,'con.prev');return checkServiceCode('remoteCtr','S00','144');" title="이전">이전</a>
# <span class="btn_next dim">다음</span>
# <span class="btn_next_end dim">맨 마지막</span>
# </div>
# <div class="pg_area">
# <input alt="이동 페이지입력" id="comicSequence" onclick="return clickInputFocus(event, this)" onkeyup="moveArticleByEnterKey(event, 'webtoon',748105,'comicSequence')" style="width:31px" title="이동 페이지입력" type="text" value="145"/>
# <span>/</span>
# <span class="total">145</span>
# <a class="btn_move" href="#" id="goButton" onclick="moveArticleByTitleIdSeq('webtoon',748105,'comicSequence')"><span class="blind">이동</span></a>
# </div>
# <div class="pg_area2">
# <a class="btn_up" href="#@" onclick="javascript:nclk_v2(event,'con.up'); goUp(); return false;">맨위로</a>
# <a class="btn_down" href="#@" onclick="javascript:nclk_v2(event,'con.down'); goDown(); return false;">아래로</a>
# <a class="btn_lst" href="/webtoon/list?titleId=748105" onclick="nclk_v2(event,'con.list')">목록</a>
# </div>
# </div>
# <a class="btn_clse" href="#" id="butt" onclick="nclk_v2(event,'con.close'); return false;" title="닫기">닫기</a>
# <!-- //리모컨 -->
# </div></dd></dl>
# </div>
# </div>
# <div class="view_area" id="comic_view_area">
# <!-- 뷰어  -->
# <div class="wt_viewer" style="background:#FFFFFF">
# <img alt="comic content" oncontextmenu="return false" ondragstart="return false" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" onselectstart="return false" src="https://image-comic.pstatic.net/webtoon/img-ctguide-white.png" title=""/>
# <img alt="comic content" class="" id="content_image_0" oncontextmenu="return false" ondragstart="return false" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" onselectstart="return false" src="https://image-comic.pstatic.net/webtoon/748105/145/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_1.jpg" title=""/>
# <img alt="comic content" class="" id="content_image_1" oncontextmenu="return false" ondragstart="return false" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" onselectstart="return false" src="https://image-comic.pstatic.net/webtoon/748105/145/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_2.jpg" title=""/>
# <img alt="comic content" class="" id="content_image_2" oncontextmenu="return false" ondragstart="return false" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" onselectstart="return false" src="https://image-comic.pstatic.net/webtoon/748105/145/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_3.jpg" title=""/>
# <img alt="comic content" class="" id="content_image_3" oncontextmenu="return false" ondragstart="return false" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" onselectstart="return false" src="https://image-comic.pstatic.net/webtoon/748105/145/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_4.jpg" title=""/>
# <img alt="comic content" class="" id="content_image_4" oncontextmenu="return false" ondragstart="return false" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" onselectstart="return false" src="https://image-comic.pstatic.net/webtoon/748105/145/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_5.jpg" title=""/>
# <img alt="comic content" class="" id="content_image_5" oncontextmenu="return false" ondragstart="return false" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" onselectstart="return false" src="https://image-comic.pstatic.net/webtoon/748105/145/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_6.jpg" title=""/>
# <img alt="comic content" class="" id="content_image_6" oncontextmenu="return false" ondragstart="return false" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" onselectstart="return false" src="https://image-comic.pstatic.net/webtoon/748105/145/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_7.jpg" title=""/>
# <img alt="comic content" class="" id="content_image_7" oncontextmenu="return false" ondragstart="return false" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" onselectstart="return false" src="https://image-comic.pstatic.net/webtoon/748105/145/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_8.jpg" title=""/>
# <img alt="comic content" class="" id="content_image_8" oncontextmenu="return false" ondragstart="return false" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" onselectstart="return false" src="https://image-comic.pstatic.net/webtoon/748105/145/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_9.jpg" title=""/>
# <img alt="comic content" class="" id="content_image_9" oncontextmenu="return false" ondragstart="return false" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" onselectstart="return false" src="https://image-comic.pstatic.net/webtoon/748105/145/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_10.jpg" title=""/>
# <img alt="comic content" class="" id="content_image_10" oncontextmenu="return false" ondragstart="return false" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" onselectstart="return false" src="https://image-comic.pstatic.net/webtoon/748105/145/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_11.jpg" title=""/>
# <img alt="comic content" class="" id="content_image_11" oncontextmenu="return false" ondragstart="return false" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" onselectstart="return false" src="https://image-comic.pstatic.net/webtoon/748105/145/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_12.jpg" title=""/>
# <img alt="comic content" class="" id="content_image_12" oncontextmenu="return false" ondragstart="return false" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" onselectstart="return false" src="https://image-comic.pstatic.net/webtoon/748105/145/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_13.jpg" title=""/>
# <img alt="comic content" class="" id="content_image_13" oncontextmenu="return false" ondragstart="return false" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" onselectstart="return false" src="https://image-comic.pstatic.net/webtoon/748105/145/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_14.jpg" title=""/>
# <img alt="comic content" class="" id="content_image_14" oncontextmenu="return false" ondragstart="return false" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" onselectstart="return false" src="https://image-comic.pstatic.net/webtoon/748105/145/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_15.jpg" title=""/>
# <img alt="comic content" class="" id="content_image_15" oncontextmenu="return false" ondragstart="return false" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" onload="loadImageEvent(this);" onselectstart="return false" src="https://image-comic.pstatic.net/webtoon/748105/145/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_16.jpg" title=""/>
# </div>
# <!-- //뷰어 -->
# <div class="ads_sc" id="ppl_default_section" style="display:none;"></div>
# <div class="ppl_story_wrap" id="ppl_story_section" style="background: #FFFFFF; display: none;">
# <!-- [D] 스토리형 PPL : 블랙 배경인경우 black 클래스 추가 -->
# <div class="ppl_story" id="ppl_story_content">
# <div class="ppl_txt"><span class="ico_ad">AD</span>여기서부터 광고!</div>
# </div>
# </div>
# <div class="ads_sc" id="ppl_image_section" style="display:none;">
# <a href="#" id="ppl_link_tag" onclick="nclk_v2(event,'llw.img','570503-23');" target="_blank">
# <img alt="" class="" id="ppl_image_area" oncontextmenu="return false" ondragstart="return false" onload="" onselectstart="return false" src="" title=""/>
# </a>
# <a class="adsby" href="https://comic.naver.com/business/proposalGuide"><img alt="Ads by Naver WEBTOON" height="17" src="https://ssl.pstatic.net/static/comic/images/txt_ads_v2.png" width="201"/></a>
# </div>
# <div class="ads_sc video" id="ppl_video_section" style="display:none;">
# <div id="ppl_video_area">
# <div class="ads_image_area">
# <a class="_ppl_video_top_image_link" href="#" onclick="javascript:nclk_v2(event, 'vad.img');" target="_blank">
# <img alt="AD Image" class="_ppl_video_affordance_link" height="260" id="ppl_video_top_image" width="600"/>
# </a>
# </div>
# <div class="ads_video_area">
# <div class="support_no"><a class="_ppl_video_affordance_link" href="#" target="_blank"><img alt="AD" height="340" id="ppl_video_no_support_image" width="600"/></a></div>
# <div class="support">
# <video class="ads_video" height="340" id="flexVideo" muted="" width="600">
# <source id="ppl_video_mp4_source" type="video/mp4"/>
# </video>
# <a class="btn_mov_play" href="#none" onclick="javascript:nclk_v2(event, 'vad.stopplay');">재생</a>
# <button class="btn_volume off _video_ad_btn_volume" id="pplBigBannerSoundBtn" onclick="javascript:nclk_v2(event, 'vad.sound');" title="Sound off" type="button">Sound off</button>
# <a class="lk_detail _ppl_video_affordance_link" href="#none" id="pplBigBannerDetailBtn" target="_blank">자세히 보기</a>
# <a class="btn_full _video_ad_btn_full" href="#none" id="pplBigBannerFullScreenBtn" onclick="javascript:nclk_v2(event, 'vad.expand');" title="전체화면 보기">전체화면 보기</a>
# <span class="video_mask" style="display:none"></span>
# <span class="video_shadow" style="display:none"></span>
# <span class="video_outline" style="display:none"></span>
# </div>
# </div>
# </div>
# <!-- [D] 컬러 변경시 on 클래스 추가 -->
# <a class="advertiser_text _ppl_video_affordance_link" href="#" id="pplAdvertiserTextBtn" target="_blank"></a>
# <a class="adsby _ppl_video_affordance_link" href="https://comic.naver.com/business/proposalGuide" id="pplAdsbyBtn" target="_blank"><img alt="Ads by Naver WEBTOON 네이버 홈으로 이동" height="17" src="https://ssl.pstatic.net/static/comic/images/txt_ads_v2.png" width="201"/></a>
# </div>
# <div class="btn_w">
# <!-- 좋아요 -->
# <div class="u_likeit_module"></div>
# <!-- //좋아요 -->
# <!-- 소셜플러그인 -->
# <div class="spiLayer" id="spiLayer">
# <div class="naver-splugin" data-oninitialize="getInitialParams();"></div>
# </div>
# <!-- //소셜플러그인 -->
# </div>
# <div class="view_sub">
# <div class="tag">
# <a class="first" href="/tagList?tag=%eb%8f%85%eb%a6%bd%ec%9d%bc%ea%b8%b0" onclick="nclk_v2(event,'bdb.tag','','1')">
# 											독립일기
# 										</a>
# </div>
# <div class="scrap">
# <a href="#" onclick="nclk_v2(event,'bdb.bookmark'); clickBookmark('/mypage/bookmarkAdd?titleId=748105&amp;no=145')">책갈피하기</a>
# </div>
# </div>
# </div>
# <div class="vote_lst">
# <dl class="lt">
# <dt><img alt="회별별점" height="11" src="https://ssl.pstatic.net/static/comic/images/migration/detail/txt_point_all.gif" width="39"/></dt>
# <dd class="total">
# <div class="rating_type4" id="bottomTotalStarPoint">
# <span class="star"><em style="width:99%">평점</em></span>
# <span id="bottomPointTotalNumber"><strong>9.98</strong></span>
# <span class="pointTotalPerson">(참여 <em>13384</em>)</span>
# </div>
# </dd>
# <dt id="bottomStarLabel"><img alt="별점주기" class="starscore_guide_txt" height="11" src="https://ssl.pstatic.net/static/comic/images/migration/detail/txt_point_click.gif" width="38"/></dt>
# <dd id="bottomStarSelectbox">
# <div class="pointSelect fl">
# <a class="default" href="#" id="starScoreMenu_2" onclick="nclk_v2(event,'bdb.star','','11')"><span class="star_type4"><span class="mask" id="bottomTargetMask" style="width:100%"><img alt="점수선택" class="starscore_star_pic" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/ico_star_n.gif" width="60"/></span></span></a>
# <ul id="pointSelectOption_2" style="display:none;">
# <li><a href="#" id="bottomStar10Select" onclick="nclk_v2(event,'bdb.star','','10')" title="10점"><span class="star_type4"><span class="mask" style="width:100%"><img alt="10점" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/ico_star_n.gif" width="60"/>10점</span></span></a></li>
# <li><a href="#" id="bottomStar9Select" onclick="nclk_v2(event,'bdb.star','','9')" title="9점"><span class="star_type4"><span class="mask" style="width:90%"><img alt="9점" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/ico_star_n.gif" width="60"/>9점</span></span></a></li>
# <li><a href="#" id="bottomStar8Select" onclick="nclk_v2(event,'bdb.star','','8')" title="8점"><span class="star_type4"><span class="mask" style="width:80%"><img alt="8점" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/ico_star_n.gif" width="60"/>8점</span></span></a></li>
# <li><a href="#" id="bottomStar7Select" onclick="nclk_v2(event,'bdb.star','','7')" title="7점"><span class="star_type4"><span class="mask" style="width:70%"><img alt="7점" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/ico_star_n.gif" width="60"/>7점</span></span></a></li>
# <li><a href="#" id="bottomStar6Select" onclick="nclk_v2(event,'bdb.star','','6')" title="6점"><span class="star_type4"><span class="mask" style="width:60%"><img alt="6점" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/ico_star_n.gif" width="60"/>6점</span></span></a></li>
# <li><a href="#" id="bottomStar5Select" onclick="nclk_v2(event,'bdb.star','','5')" title="5점"><span class="star_type4"><span class="mask" style="width:50%"><img alt="5점" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/ico_star_n.gif" width="60"/>5점</span></span></a></li>
# <li><a href="#" id="bottomStar4Select" onclick="nclk_v2(event,'bdb.star','','4')" title="4점"><span class="star_type4"><span class="mask" style="width:40%"><img alt="4점" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/ico_star_n.gif" width="60"/>4점</span></span></a></li>
# <li><a href="#" id="bottomStar3Select" onclick="nclk_v2(event,'bdb.star','','3')" title="3점"><span class="star_type4"><span class="mask" style="width:30%"><img alt="3점" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/ico_star_n.gif" width="60"/>3점</span></span></a></li>
# <li><a href="#" id="bottomStar2Select" onclick="nclk_v2(event,'bdb.star','','2')" title="2점"><span class="star_type4"><span class="mask" style="width:20%"><img alt="2점" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/ico_star_n.gif" width="60"/>2점</span></span></a></li>
# <li><a href="#" id="bottomStar1Select" onclick="nclk_v2(event,'bdb.star','','1')" title="1점"><span class="star_type4"><span class="mask" style="width:10%"><img alt="1점" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/ico_star_n.gif" width="60"/>1점</span></span></a></li>
# </ul>
# </div>
# <a class="btn_bx fl" href="#" id="bottomStarScoreSubmitButton" onclick="nclk_v2(event,'bdb.starok');"><span>확인</span></a>
# </dd>
# <dd class="txt" id="bottomStarText" style="display:none;"><span>참여하셨습니다.</span></dd>
# </dl>
# </div>
# <div class="band_banner">
# <a href="https://series.naver.com/comic/detail.nhn?originalProductId=401662" onclick="nclk_v2(event,'end.banner');" target="_blank">
# <img alt=" 다음 화를 미리 만나보세요! 만화 스토어에서 구매 후 이용 가능합니다. 스토어 바로가기" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" src="https://image-comic.pstatic.net/banner/store/banner_b788ef9e-8faa-41d7-8668-229d05d3b636.jpg"/>
# </a>
# </div>
# <div class="nav_area" id="comicNavigation">
# <div class="comic_lst" id="comic_body">
# <div class="inner_lst" id="comic_move">
# <div class="item" style="left:-1px;">
# <a href="/webtoon/detail?titleId=748105&amp;no=142&amp;weekday=thu" onclick="nclk_v2(event,'lst.img','748105','142')">
# <span class="thmb">
# <img alt="시즌2 39화 세상의 모든 알람" height="42" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non70_42.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/748105/142/thumbnail_202x120_0b8733fd-f346-4819-93db-9501c5b36d95.jpg" width="70">
# <span class="mask"></span>
# </img></span>
# <span class="subj">시즌2 39화 세상의 모든 알람</span>
# </a>
# </div>
# <div class="item" style="left:120px;">
# <a href="/webtoon/detail?titleId=748105&amp;no=143&amp;weekday=thu" onclick="nclk_v2(event,'lst.img','748105','143')">
# <span class="thmb">
# <img alt="시즌2 40화 깐부" height="42" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non70_42.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/748105/143/thumbnail_202x120_b3ebf09a-c025-423e-8dfe-852b00f91616.jpg" width="70">
# <span class="mask"></span>
# </img></span>
# <span class="subj">시즌2 40화 깐부</span>
# </a>
# </div>
# <div class="item" style="left:241px;">
# <a href="/webtoon/detail?titleId=748105&amp;no=144&amp;weekday=thu" onclick="nclk_v2(event,'lst.img','748105','144')">
# <span class="thmb">
# <img alt="시즌2 41화 우리 집 산타" height="42" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non70_42.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/748105/144/thumbnail_202x120_60e88c76-8eab-488b-8e85-5f8a98cee8f3.jpg" width="70">
# <span class="mask"></span>
# </img></span>
# <span class="subj">시즌2 41화 우리 집 산타</span>
# </a>
# </div>
# <div class="item" style="left:362px;">
# <a class="on" href="/webtoon/detail?titleId=748105&amp;no=145&amp;weekday=thu" onclick="nclk_v2(event,'lst.img','748105','145')">
# <span class="thmb">
# <img alt="시즌2 42화 시간제 캠핑" height="42" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non70_42.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/748105/145/thumbnail_202x120_0d81306a-5cc2-40cc-95b7-26960d56af21.jpg" width="70">
# <span class="mask"></span>
# </img></span>
# <span class="subj">시즌2 42화 시간제 캠핑</span>
# </a>
# </div>
# <div class="item" style="left:483px;"></div>
# <div class="item" style="left:604px;"></div>
# <div class="item" style="left:725px;"></div>
# </div>
# </div>
# <div class="btn_group">
# <div class="comic">
# <a class="bookmark_toon" onclick="return actionRunner.addFavoriteWebtoon('748105', 'sub', event)" title="관심웹툰"><span class="blind">관심웹툰</span></a>
# <a class="first" href="#" onclick="nclk_v2(event,'lst.firt');return checkServiceCode('subTitle','S00','1');" title="첫회보기"><span class="blind">첫회보기</span></a>
# <a class="lst" href="/webtoon/list?titleId=748105&amp;weekday=thu" onclick="nclk_v2(event,'lst.list')" title="목록보기"><span class="blind">목록보기</span></a>
# </div>
# <a class="pre" href="#" id="comic_before" onclick="nclk_v2(event,'lst.prev'); return false;" title="이전"><span class="blind">이전</span></a>
# <a class="next" href="#" id="comic_after" onclick="nclk_v2(event,'lst.next'); return false;" style="visibility:hidden;" title="다음"><span class="blind">다음</span></a>
# </div>
# </div>
# </div>
# <div class="section_cont">
# <div class="sub_cont">
# <div class="writer_info">
# <h4><img alt="작가의 말" height="14" src="https://ssl.pstatic.net/static/comic/images/migration/detail/h_writer.gif" width="57"/><em class="name">
# 							(<strong>자까</strong>)
# 						</em></h4>
# <p>.</p>
# <ul class="btn_group" id="btn_group">
# <li><a alt="작가의 다른 작품" class="other" href="#" onclick="nclk_v2(event,'sub.artist'); return actionRunner.artistForArtistTitle(this);" title="작가의 다른 작품"><span class="blind">작가의 다른 작품</span></a></li>
# <li><a class="blog" href="#" onclick="nclk_v2(event,'sub.blog'); return actionRunner.artistForBlogUrl(this);" title="작가 블로그"><span class="blind">작가 블로그</span></a></li>
# <li><a class="cafe" href="#" onclick="nclk_v2(event,'sub.fancafe'); return actionRunner.artistFanCafe(this);" title="팬카페"><span class="blind">팬카페</span></a></li>
# <li></li>
# </ul>
# </div>
# <div class="ad_banner_premium">
# <div id="webtoonEndAd"></div>
# <div data-ad-banner="premium_banner" id="premium_banner"></div>
# <script>
#     if (navigator.userAgent.toLowerCase().indexOf("msie") === -1) {
#         const script = document.createElement('script');
#         script.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#         document.head.appendChild(script);
#         window.gladsdk = window.gladsdk || { cmd: [] };
#         gladsdk.cmd.push(function() {
#             gladsdk.defineAdSlot({
#                 adUnitId: "p_webtoon_reply_top",
#                 adSlotElementId: "webtoonEndAd",
#             });
#             gladsdk.displayAd("webtoonEndAd");
#         });
#     }
# </script>
# </div>
# <iframe frameborder="0" id="commentIframe" scrolling="no" style="min-height:500px" title="독립일기 - 시즌2 42화 시간제 캠핑 댓글영역" width="100%"></iframe>
# <!-- 최신 업데이트 웹툰  -->
# <div class="new_comic">
# <h4><img alt="최신 업데이트 웹툰" height="15" src="https://ssl.pstatic.net/static/comic/images/migration/detail/h_tit_new_v2.gif" width="113"/></h4>
# <ul class="lst_new">
# <li class="line_none">
# <div class="thmb">
# <a href="/bestChallenge/list?titleId=788319" onclick="nclk_v2(event,'new.img','748105','1')">
# <img alt="인간동물원" class="dataImg" height="101" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non125_101.gif'" src="https://shared-comic.pstatic.net/thumb/nas/user_contents_data/challenge_comic/2022/01/21/317061/thumbnail_125x101e5798ce7_e60c_4813_a827_8d9d746ae2db_00001078.JPEG" title="인간동물원" width="125"/>
# <span class="mask"></span>
# </a>
# </div>
# <p>
# <img alt="베스트" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/ico_best.gif" title="베스트" width="23"/>
# <a href="/bestChallenge/list?titleId=788319" onclick="nclk_v2(event,'new.title','748105','1')">인간동물원</a>
# </p>
# </li>
# <li>
# <div class="thmb">
# <a href="/bestChallenge/list?titleId=676543" onclick="nclk_v2(event,'new.img','748105','2')">
# <img alt="원인탐구생활" class="dataImg" height="101" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non125_101.gif'" src="https://shared-comic.pstatic.net/thumb/nas/user_contents_data/challenge_comic/2019/03/10/299955/thumbnail_125x1015272d528_cc28_4e1a_87df_0ea622d607a3_00001213.JPEG" title="원인탐구생활" width="125"/>
# <span class="mask"></span>
# </a>
# </div>
# <p>
# <img alt="베스트" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/ico_best.gif" title="베스트" width="23"/>
# <a href="/bestChallenge/list?titleId=676543" onclick="nclk_v2(event,'new.title','748105','2')">원인탐구생활</a>
# </p>
# </li>
# <li>
# <div class="thmb">
# <a href="/bestChallenge/list?titleId=779079" onclick="nclk_v2(event,'new.img','748105','3')">
# <img alt="미필은 노하이" class="dataImg" height="101" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non125_101.gif'" src="https://shared-comic.pstatic.net/thumb/nas/user_contents_data/challenge_comic/2021/12/04/327366/thumbnail_125x101c9886f0d_a9e9_4368_8203_6a0c1ab090a2_00001395.JPEG" title="미필은 노하이" width="125"/>
# <span class="mask"></span>
# </a>
# </div>
# <p>
# <img alt="베스트" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/ico_best.gif" title="베스트" width="23"/>
# <a href="/bestChallenge/list?titleId=779079" onclick="nclk_v2(event,'new.title','748105','3')">미필은 노하이</a>
# </p>
# </li>
# <li>
# <div class="thmb">
# <a href="/bestChallenge/list?titleId=785970" onclick="nclk_v2(event,'new.img','748105','4')">
# <img alt="학교가는 고등어" class="dataImg" height="101" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non125_101.gif'" src="https://shared-comic.pstatic.net/thumb/nas/user_contents_data/challenge_comic/2021/12/04/351665/thumbnail_125x101dd7fe736_767c_4026_9ef8_35ce63cdfd15_00001227.JPEG" title="학교가는 고등어" width="125"/>
# <span class="mask"></span>
# </a>
# </div>
# <p>
# <img alt="베스트" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/ico_best.gif" title="베스트" width="23"/>
# <a href="/bestChallenge/list?titleId=785970" onclick="nclk_v2(event,'new.title','748105','4')">학교가는 고등어</a>
# </p>
# </li>
# </ul>
# </div>
# <!-- //최신 업데이트 웹툰  -->
# </div>
# <div id="aside">
# <div class="aside_product_ban">
# <a href="https://tumblbug.com/jaggamoodbin" onclick="nclk_v2(event,'prd.banner', '748105_2120');" target="self">
# <img alt="" height="183" src="https://naverwebtoon-phinf.pstatic.net/20220103_19/1641204403040zH6KN_JPEG/upload_8843952275332102961.JPEG" width="240"/>
# </a>
# </div>
# <!-- 인기급상승웹툰 -->
# <div class="asideBox">
# <h4 class="asideBoxTitle"><img alt="인기급상승웹툰" height="11" src="https://ssl.pstatic.net/static/comic/images/migration/common/subtlt_r_best_v2.gif" title="인기급상승웹툰" width="78"/></h4>
# <div>
# <ul class="asideBoxTab"><!-- 선택된 메뉴에는 choice라는 클래스명을 사용합니다 -->
# <li class="choice" id="realTimeRankChoiceTabFavorite"><a href="#" id="realTimeRankChoiceTabFavoriteClick" onclick="nclk_v2(event,'rnk.rep')"><img alt="인기순" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/tab_txt_favor.gif" title="인기순" width="31"/></a></li>
# <li id="realTimeRankChoiceTabUpdate"><a href="#" id="realTimeRankChoiceTabUpdateClick" onclick="nclk_v2(event,'rnk.upd')"><img alt="업데이트순" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/tab_txt_update.gif" title="업데이트순" width="52"/></a></li>
# </ul>
# <h3 class="blind" id="realTimeRankBlindName">인기순</h3>
# <ol class="asideBoxRank" id="realTimeRankFavorite">
# <li class="rank01">
# <a href="/webtoon/detail?titleId=641253&amp;no=376" onclick="nclk_v2(event,'rnk*p.cont','641253','1')" title="외모지상주의-376화 일해회 (2계열사) [05]">외모지상주의-376화 일해회 (2계열사) [05]</a>
# <span class="rankBox">
# <img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0
#
#
# 				</span>
# </li>
# <li class="rank02">
# <a href="/webtoon/detail?titleId=773797&amp;no=28" onclick="nclk_v2(event,'rnk*p.cont','773797','2')" title="나 혼자 만렙 뉴비-27화. 고인물이 성장하는 법(2)">나 혼자 만렙 뉴비-27화. 고인물이 성장하는 법(2)</a>
# <span class="rankBox">
# <img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0
#
#
# 				</span>
# </li>
# <li class="rank03">
# <a href="/webtoon/detail?titleId=735661&amp;no=101" onclick="nclk_v2(event,'rnk*p.cont','735661','3')" title="재혼 황후-98화">재혼 황후-98화</a>
# <span class="rankBox">
# <img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0
#
#
# 				</span>
# </li>
# <li class="rank04">
# <a href="/webtoon/detail?titleId=772764&amp;no=37" onclick="nclk_v2(event,'rnk*p.cont','772764','4')" title="죽지 않으려면-37화">죽지 않으려면-37화</a>
# <span class="rankBox">
# <img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0
#
#
# 				</span>
# </li>
# <li class="rank05">
# <a href="/webtoon/detail?titleId=318995&amp;no=534" onclick="nclk_v2(event,'rnk*p.cont','318995','5')" title="갓 오브 하이스쿨-530화">갓 오브 하이스쿨-530화</a>
# <span class="rankBox">
# <img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0
#
#
# 				</span>
# </li>
# <li class="rank06">
# <a href="/webtoon/detail?titleId=776601&amp;no=28" onclick="nclk_v2(event,'rnk*p.cont','776601','6')" title="광마회귀-28화">광마회귀-28화</a>
# <span class="rankBox">
# <img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0
#
#
# 				</span>
# </li>
# <li class="rank07">
# <a href="/webtoon/detail?titleId=725586&amp;no=151" onclick="nclk_v2(event,'rnk*p.cont','725586','7')" title="1초-150화 구조대 본시험 1주차 (4)">1초-150화 구조대 본시험 1주차 (4)</a>
# <span class="rankBox">
# <img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0
#
#
# 				</span>
# </li>
# <li class="rank08">
# <a href="/webtoon/detail?titleId=712362&amp;no=155" onclick="nclk_v2(event,'rnk*p.cont','712362','8')" title="개를 낳았다-시즌2 81화">개를 낳았다-시즌2 81화</a>
# <span class="rankBox">
# <img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0
#
#
# 				</span>
# </li>
# <li class="rank09">
# <a href="/webtoon/detail?titleId=781354&amp;no=17" onclick="nclk_v2(event,'rnk*p.cont','781354','9')" title="내과 박원장-17화. 운수 좋은 날">내과 박원장-17화. 운수 좋은 날</a>
# <span class="rankBox">
# <img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0
#
#
# 				</span>
# </li>
# <li class="rank10">
# <a href="/webtoon/detail?titleId=773476&amp;no=34" onclick="nclk_v2(event,'rnk*p.cont','773476','10')" title="서울역 드루이드-34화">서울역 드루이드-34화</a>
# <span class="rankBox">
# <img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0
#
#
# 				</span>
# </li>
# </ol>
# <ol class="asideBoxRank" id="realTimeRankUpdate" style="display:none;">
# <li class="rank01">
# <a href="/webtoon/detail?titleId=552960&amp;no=410" onclick="nclk_v2(event,'rnk*u.cont','552960','1')" title="더 게이머-5부 60화">
#
# 					더 게이머-5부 60화
# 				</a>
# <span class="timeBox">
#
#
#
# 							12시간전
#
#
#
#
#
# 				</span>
# </li>
# <li class="rank02">
# <a href="/webtoon/detail?titleId=759457&amp;no=55" onclick="nclk_v2(event,'rnk*u.cont','759457','2')" title="여성전용헬스장 진달래짐-54화: 요요극복 프로젝트">
#
# 					여성전용헬스장 진달래짐-54화: 요요극복 프로젝트
# 				</a>
# <span class="timeBox">
#
#
#
# 							12시간전
#
#
#
#
#
# 				</span>
# </li>
# <li class="rank03">
# <a href="/webtoon/detail?titleId=764040&amp;no=54" onclick="nclk_v2(event,'rnk*u.cont','764040','3')" title="빨리감기-후기">
#
# 					빨리감기-후기
# 				</a>
# <span class="timeBox">
#
#
#
# 							12시간전
#
#
#
#
#
# 				</span>
# </li>
# <li class="rank04">
# <a href="/webtoon/detail?titleId=735661&amp;no=101" onclick="nclk_v2(event,'rnk*u.cont','735661','4')" title="재혼 황후-98화">
#
# 					재혼 황후-98화
# 				</a>
# <span class="timeBox">
#
#
#
# 							12시간전
#
#
#
#
#
# 				</span>
# </li>
# <li class="rank05">
# <a href="/webtoon/detail?titleId=745876&amp;no=90" onclick="nclk_v2(event,'rnk*u.cont','745876','5')" title="플레이어-90화">
#
# 					플레이어-90화
# 				</a>
# <span class="timeBox">
#
#
#
# 							12시간전
#
#
#
#
#
# 				</span>
# </li>
# <li class="rank06">
# <a href="/webtoon/detail?titleId=753478&amp;no=73" onclick="nclk_v2(event,'rnk*u.cont','753478','6')" title="데드퀸-73화">
#
# 					데드퀸-73화
# 				</a>
# <span class="timeBox">
#
#
#
# 							12시간전
#
#
#
#
#
# 				</span>
# </li>
# <li class="rank07">
# <a href="/webtoon/detail?titleId=761722&amp;no=57" onclick="nclk_v2(event,'rnk*u.cont','761722','7')" title="세기말 풋사과 보습학원-57화">
#
# 					세기말 풋사과 보습학원-57화
# 				</a>
# <span class="timeBox">
#
#
#
# 							12시간전
#
#
#
#
#
# 				</span>
# </li>
# <li class="rank08">
# <a href="/webtoon/detail?titleId=773916&amp;no=33" onclick="nclk_v2(event,'rnk*u.cont','773916','8')" title="말년용사-33화">
#
# 					말년용사-33화
# 				</a>
# <span class="timeBox">
#
#
#
# 							12시간전
#
#
#
#
#
# 				</span>
# </li>
# <li class="rank09">
# <a href="/webtoon/detail?titleId=758660&amp;no=30" onclick="nclk_v2(event,'rnk*u.cont','758660','9')" title="네버엔딩달링-30화">
#
# 					네버엔딩달링-30화
# 				</a>
# <span class="timeBox">
#
#
#
# 							12시간전
#
#
#
#
#
# 				</span>
# </li>
# <li class="rank10">
# <a href="/webtoon/detail?titleId=777272&amp;no=26" onclick="nclk_v2(event,'rnk*u.cont','777272','10')" title="식인귀-26화 - 인어 사냥꾼">
#
# 					식인귀-26화 - 인어 사냥꾼
# 				</a>
# <span class="timeBox">
#
#
#
# 							12시간전
#
#
#
#
#
# 				</span>
# </li>
# </ol>
# </div>
# </div>
# <!-- //인기급상승웹툰 -->
# <!-- 이 작품 독자들이 많이 본 웹툰 -->
# <!-- //이 작품 독자들이 많이 본 웹툰 -->
# <script>
# function goRollingLink() {
#
#
# 		document.location = "https://comic.naver.com/webtoon/list.nhn?titleId=787465";
#
# }
# </script>
# <!-- 롤링이미지 -->
# <div align="center" alt="내 짝꿍은 로봇? &lt;철수와 영희 이야기&gt;" class="asideRolling" onclick="nclk_v2(event,'olk.banner'); goRollingLink();" style="cursor:pointer;width:240px;height:97px;background-image:URL('https://naverwebtoon-phinf.pstatic.net/20220124_59/1642987979087FdfPC_JPEG/upload_5627954965749633351.JPEG?type=p100')"></div>
# </div>
# </div>
# <form action="/requestFancafe" method="get" name="request_fancafe_form">
# <input name="painterId" type="hidden" value="자까"/>
# ...
#  			window.clipboardData.setData('Text','https://' + location.hostname + '/webtoon/detail?titleId=748105&no=145' );
#  			return true;
# 		} else {
# 			alert('복사 기능을 지원하지 않는 브라우저입니다.');
# 			return false;
# 		}
# 	}
#     var actionRunner;
#
#     WebtoonArtistActionRunner = $Class ({
#         $init : function(titleId) {
#             this._titleId = titleId;
#         },
#
#         addFavoriteWebtoon : function (titleId, nclickArea, event) {
# 	    	var width = (screen.width / 2) - 800;
# 			var height = (screen.height / 2) - 510;
# 			var favoriteUrl = null;
# 			var addUrl = "https://" + location.hostname + "/mypage/favoriteTitleAdd?titleId="+titleId;
# 			var removeUrl = "https://" + location.hostname + "/mypage/favoriteTitleRemove?titleId="+titleId;
# 			if($Element(jindo.$$.getSingle('.book_maker')).hasClass('on')) {
# 				favoriteUrl = removeUrl;
#                 nclk_v2(event, nclickArea + '.zzimdel');
# 			} else {
# 				favoriteUrl = addUrl;
# 				console.log(event);
#                 nclk_v2(event, nclickArea + '.zzim');
# 			}
#
# 			if(isLogin) {
# 			    var favoritePopup = window.open('', 'addFavorite', 'directories=no,toolbar=no,scrollbars=yes,width=370,height=180,top=' + height + ',left=' + width);
# 			    favoritePopup.location.href = favoriteUrl;
# 			} else {
# 			    location.href = "/common/login?url=" + encodeURIComponent(location.href);
# 			}
# 	    },
#
# 		artistForArtistTitle : function(element) {
# 			$Element("author_layer_inner").html("");
# 			$Element("author_layer").css("border", "");
# 			$Element("author_layer_inner").css("border", "1px solid #c5c5c5");
#
# 			if(artistData.length == 0) {
# 				var liElement = new $Element("<li>");
# 				var spanElement = new $Element("<span>");
# 				spanElement.html("작가의 다른 작품이 없습니다.");
# 				liElement.append(spanElement);
# 				$Element("author_layer_inner").append(liElement);
# 				artistLayer.show(element);
# 			} else if(artistData.length == 1) {
# 				location.href = "/artistTitle?artistId=" + artistData[0].artistId;
# 			} else {
# 				for (var i = 0; i < artistData.length; i++) {
# 					var liElement = new $Element("<li>");
# 					var aElement = new $Element("<a>");
# 					aElement.attr("href", "/artistTitle?artistId=" + artistData[i].artistId);
# 					aElement.html("<span>&lt;" + artistData[i].nickname + "</span>&gt;의 다른작품");
# 					liElement.append(aElement);
# 					$Element("author_layer_inner").append(liElement);
# 					if (i==9) {
# 						$Element("author_layer").css("border", "1px solid #c5c5c5");
# 						$Element("author_layer_inner").css("border", "0");
# 					}
# 				}
# 				artistLayer.show(element);
# 			}
# 			return false;
# 		},
#
#         artistForBlogUrl : function(element) {
#         	if (currentLevelName == 'WEBTOON' && artistData.length == 1 && $S(artistData[0].blogUrl).trim().$value() != '') {
#         		window.open(artistData[0].blogUrl, '_blank');
#         		return false;
#         	} else {
# 	        	$Element("author_layer_inner").html("");
# 	        	$Element("author_layer").css("border", "");
# 				$Element("author_layer_inner").css("border", "1px solid #c5c5c5");
#
#                 var blogCount = 0;
# 	            if (currentLevelName == 'WEBTOON') {
#
# 	                for (var i = 0; i < artistData.length; i++) {
# 	                    if ($S(artistData[i].blogUrl).trim().$value() != '') {
# 		                    var liElement = new $Element("<li>");
# 		                    var aElement = new $Element("<a>");
# 		                    aElement.attr("href", artistData[i].blogUrl);
# 		                    aElement.attr("target", "_blank");
# 							aElement.html("<span>&lt;" + artistData[i].nickname + "</span>&gt;의 블로그");
#
# 		                    liElement.append(aElement);
# 		                    $Element("author_layer_inner").append(liElement);
# 		                    blogCount++;
#
# 		                    if (i==9) {
# 		                        $Element("author_layer").css("border", "1px solid #c5c5c5");
# 		                        $Element("author_layer_inner").css("border", "0");
# 		                    }
# 	                    }
# 	                }
# 	                if (blogCount == 0) {
# 	                    var liElement = new $Element("<li>");
# 	                    var aElement = new $Element("<a>");
# 	                    aElement.html("등록된 블로그가 없습니다.");
#
# 	                    liElement.append(aElement);
# 	                    $Element("author_layer_inner").append(liElement);
# 	                }
# 	            } else {
# 	                for (var i = 0; i < artistData.length; i++) {
# 	                    var liElement = new $Element("<li>");
# 	                    var aElement = new $Element("<a>");
# 	                    aElement.attr("href", artistData[i].blogUrl);
# 	                    aElement.attr("target", "_blank");
# 						aElement.html("<span>&lt;" + artistData[i].nickname + "</span>&gt;의 블로그");
#
# 	                    liElement.append(aElement);
# 	                    $Element("author_layer_inner").append(liElement);
#                         blogCount++;
# 	                }
#
#                     if (blogCount == 0) {
#                         var liElement = new $Element("<li>");
#                         var aElement = new $Element("<a>");
#                         aElement.html("등록된 블로그가 없습니다.");
#
#                         liElement.append(aElement);
#                         $Element("author_layer_inner").append(liElement);
#                     }
# 	            }
# 	            artistLayer.show(element);
# 	            return false;
#         	}
#         },
#
#         artistFanCafe : function(element) {
#         	var fancafeUrl = '';
#             $Element("author_layer_inner").html("");
#             $Element("author_layer").css("border", "");
# 			$Element("author_layer_inner").css("border", "1px solid #c5c5c5");
#
# 			var liElement = new $Element("<li>");
# 			var aElement = new $Element("<a>");
#
# 			if (null != fancafeUrl && '' != fancafeUrl) {
# 				aElement.attr("href", "");
# 				aElement.attr("target", "_blank");
# 				aElement.html("팬카페 바로가기")
# 			} else {
# 				aElement.attr("href", "javascript:request_fancafe()");
# 				aElement.html("팬카페 등록하기");
# 			}
# 			liElement.append(aElement);
# 			$Element("author_layer_inner").append(liElement);
#             artistLayer.show(element);
#             return false;
#         }
# 	});
#
# 	function request_fancafe() {
#
#
# 		if ( !isLogin)
# 		{
# 			if ( !confirm('로그인 해야 이용할 수 있습니다. 로그인 하겠습니까?'))
# 				return ;
#
# 			document.request_fancafe_form.refresh.value = "true";
# 		}
# 		var form = document.request_fancafe_form;
# 		nwin=open("about:blank", "request_fancafe", "top=10,left=10,toolbar=no,location=0,directories=0,status=yes,menubar=0,scrollbars=no,resizable=0,width=500,height=296");
#
# 		form.target = "request_fancafe";
# 		nwin.blur();
#
#
# 		nwin.focus();
# 		form.submit() ;
#
# 	}
#
# 	function loadThisWindow () {
# 		// 해당 페이지 정보(별점 ajax 호출 시 필요한 정보들)
# 		var oStarInfo = {
# 			"titleId" : 748105
# 			, "no" : 145
# 			, "token" : 'eyJhbGciOiJIUzI1NiJ9.eyJ0aXRsZUlkIjo3NDgxMDUsIm5vIjoxNDUsImlkTm8iOiIifQ.RfzLeWQ0zrcnYhXS8xhb2DbcIrYAzmwdMPHTPh6divo'
# 		}
# 	 	new StarScorePoll(isLogin, oStarInfo);
# 	 	new FreeComicShowHideEventRegister(newButtonObject);
#
# 		//$Element("tagBox").css("position","relative");
# 		//$Element("tagBox").css("zIndex","100");
#
# 		if(artistData.length > 1) {
# 	 		$Element("btn_group").addClass("btn_lst");
# 	 		$Element("other_content").className("other2");
# 		}
#
# 		if (false)
# 		{
# 			$Element("comic_before").css("visibility","hidden");
# 		}
# 		if (true)
# 		{
# 			$Element("comic_after").css("visibility","hidden");
# 		}
#
# 		new NavigationBar(navi_init,"/navigationToJson?ln=WEBTOON&titleId=748105&weekday=thu&articleCount=0");
# 	   	new ExtraRemover();
# 		$('commentIframe').src = sCommentUrl;
#
#         // 이미지 실제 위치
#         webtoonContentActualTopMargin = $Element($Element('comic_view_area').query('img')).offset().top ;
#
# 		// 웹툰 PPL
#
#
#         // flex 빅배너 & PPL : 웹툰 PPL이 있을 경우, 베도/도전만화인 경우 미노출되어야 함
#
# 		var oflexVideoAd = new FlexVideoAd();
# 		new FlexAd('748105', '', oflexVideoAd, '');
#
#
# 		// 초기값 체크
# 		eraseCookie("top");
# 		eraseCookie("left");
#
# 		// 리모콘 객체 생성
# 		var remocon = new RemoconComic("comicRemocon");
# 		var drag = new Drag("comicRemocon", remocon, remocon._getRemoconPos[1], remocon._getRemoconPos[1]);
#
# 		// 포텐업 버튼 이벤트
# 		if (jindo.$("potenupAreaBtn")) {
# 			jindo.$Fn(function(oEvent) {
# 				oEvent.stopDefault();
# 				jindo.$Element("potenupAreaBtn").toggleClass('on');
# 			}).attach($("potenupAreaBtn"), "click").attach($("potenupAreaCloseBtn"), "click");
# 		}
# 	}
#
# 	function goUp(){
# 	    var max = $Element('comic_view_area').offset().top;
# 	    window.scrollTo(0,0);
# 	}
#
# 	function goDown(){
#     	var max =  $Element('comic_view_area').first().height();
# 	    window.scrollTo(0,max-($Element("comicRemocon").height()));
#     }
#
# 	function doComicReport() {
# 		var isNaverLogin = false;
#
# 		if (!isNaverLogin) {
# 			if (confirm('로그인 해야 이용할 수 있습니다. 로그인 하시겠습니까?')) {
# 				location.href = 'https://nid.naver.com/nidlogin.login?mode=form&url=' + encodeURIComponent(location.href);
# 			}
# 		} else {
# 			var form = document.reportForm;
# 			var request_report = window.open("about:blank", "request_report", "top=10,left=10,toolbar=no,location=0,directories=0,status=yes,menubar=0,scrollbars=yes,resizable=no,width=580,height=800");
# 			form.target = "request_report";
# 			form.submit();
# 		}
# 	}
#
# 	$Fn(loadThisWindow).attach(window,"load");
#
# 	actionRunner = new WebtoonArtistActionRunner("748105");
#
#
#
# 	/**
# 	 * 시리즈로 이동 가능한지 확인해서 이동
# 	 *
# 	 * @params nbooksId {String} 북스 상품 ID
# 	 */
# 	function moveBookstore(nbooksId) {
# 		var result;
#
#         jQuery.ajax({
#             method: "GET",
#             url: "/api/checkTitleInSeries?nbooksId=" + nbooksId,
#             async: false,
#             success:function(res){
#                 result = res.isExist;
#             }
#         });
#
#
# 		var oInterval = setInterval(function() {
#             if (result) {
#                 window.open('https://series.naver.com/comic/detail.series?originalProductId=' + nbooksId, '_blank');
#             } else {
#                 alert('시리즈에 상품을 등록 중입니다. 잠시만 기다려주세요.');
#             }
#             clearInterval(oInterval);
#             oInterval = null;
# 		}, 200);
# 	}
# </script>
# <script type="text/javascript">
# function toogleAlert() {
# 	var alertToolTip = $("alertToolTip");
# 	if(alertToolTip.style.display == "none") {
# 		alertToolTip.style.display = "block";
# 	} else {
# 		alertToolTip.style.display = "none";
# 	}
# }
#
# </script>
# <script type="text/javascript">
#
# 	var g_ssc = "decide.me";
# 	var levelName = "WEBTOON";
# 	if(levelName == "BEST_CHALLENGE"){
#         g_ssc = "comic.best_detail";
# 	}else if(levelName == "CHALLENGE"){
#         g_ssc = "comic.chal_detail";
# 	}else if(levelName == "WEBTOON"){
#         g_ssc = "comic.toon_detail";
# 	}
# 	var ccsrv = "cc.naver.com";
# </script>
# <script type="text/javascript">
# function getInitialParams() {
#
# 	return {
#         style  : "standard",
#         text   : "black",
#         evkey  : "cartoon",
#         title  : "독립일기 - 시즌2 42화 시간제 캠핑",
#         url : location.protocol + "//comic.naver.com/webtoon/detail?titleId=748105&no=145",
#         //me2key : "cRHMQWAXT9iVoryGm_eKJQ",
#         tags   : ["웹툰", "만화", "독립일기"],
#         me : {
#             display : "off"
#         },
#         mail : {
#             display : "off"
#         },
#         cafe : {
#             sourceType : "111",
#             sourceTitle : "만화 > 독립일기 > 시즌2 42화 시간제 캠핑 | 자까",
#             sourceForm : "2"
#         },
#         blog : {
#             blogId : "naver",
#             sourceType : "111",
#             sourceTitle : "만화 > 독립일기 > 시즌2 42화 시간제 캠핑 | 자까",
#             sourceForm : "2"
#         },
#         likeServiceId : "COMIC",	// 좋아요 서비스 아이디
#         likeContentsId : "748105_145"	// 좋아요 컨텐츠 아이디
#     };
# }
#
# socialPlugin.init("https://ssl.pstatic.net/spi/js/release");
# </script>
# <script type="text/javascript">
#
#
#
# 	function callWebAdBannerView(sStatsUrl) {
# 		var self = this;
# 		var nTimestamp = new Date().getTime();
#
# 		var oAjax = new $Ajax(sStatsUrl + '&_dummy='+nTimestamp, {
# 			type : "xhr",
# 			method : "get",
# 			timeout : 3,
# 			async : false
# 		}).request();
# 	}
#
# 	function callWebAdBannerClick(sStatsUrl, sTargetUrl) {
# 		var self = this;
# 		var nTimestamp = new Date().getTime();
#
# 		var oAjax = new $Ajax(sStatsUrl + '&_dummy='+nTimestamp, {
# 			type : "xhr",
# 			method : "get",
# 			onload : function(res) {
# 				window.open(sTargetUrl, '_blank');
# 			},
# 			timeout : 3,
# 			async : false
# 		}).request();
# 	}
# </script>
# </div>
# <!-- side menu -->
# </div>
# <!-- Footer -->
# <!-- FOOTER Start -->
# <div id="footer">
# <div class="naver_corp_info">
# <ul>
# <li><a href="https://www.naver.com/rules/service.html" onclick="nclk_v2(event,'fot.agreement')" target="_blank">이용약관</a></li>
# <li><a class="privacy" href="https://www.naver.com/rules/privacy.html" onclick="nclk_v2(event,'fot.privacy')" target="_blank">개인정보처리방침</a></li>
# <li><a href="https://www.naver.com/rules/disclaimer.html" onclick="nclk_v2(event,'fot.disclaimer')" target="_blank">책임의 한계와 법적고지</a></li>
# <li><a href="https://help.naver.com/support/home.help?serviceNo=799" onclick="nclk_v2(event,'fot.helpdesk')" target="_blank" title="새 창">고객센터</a></li>
# <li><a href="/business/proposalGuide#ad" onclick="nclk_v2(event,'fot.proposal')" target="_blank">웹툰 광고 문의</a></li>
# </ul>
# <address><a href="https://www.navercorp.com/" onclick="nclk_v2(event,'fot.navercorp')" target="_blank"><span class="naver_corp_link"><span class="blind">ⓒ NAVER CORP.</span></span></a></address>
# </div>
# <div class="webtoon_corp_info">
# <ul>
# <li><a href="https://member.webtoon.naver.com/policies/terms/" target="_blank">이용약관</a></li>
# <li><a class="privacy" href="https://member.webtoon.naver.com/policies/privacy/" target="_blank">개인정보처리방침</a></li>
# <li><a href="https://member.webtoon.naver.com/policies/youthpolicy/" target="_blank">청소년보호정책</a></li>
# <li><a href="https://help.naver.com/support/service/main.help?serviceNo=799" target="_blank">웹툰 고객센터</a></li>
# <li><a href="/business/proposalGuide" target="_blank">웹툰 사업 문의</a></li>
# </ul>
# <address><a class="webtoon_corp_link" href="https://webtoonscorp.com" onclick="nclk_v2(event,'fot.wtcorp');" target="_blank"><span class="blind">ⓒ NAVER WEBTOON Limited</span></a></address>
# </div>
# <p class="copyright_law">본 콘텐츠의 저작권은 저자 또는 제공처에 있으며, 이를 무단 이용하는 경우 저작권법 등에 따라 법적 책임을 질 수 있습니다.</p>
# </div>
# <!-- //FOOTER End -->
# </div>
# <script type="text/javascript">
# 			var agent = navigator.userAgent.toLowerCase();
#
# 			function loadEvent(){
# 				try{
# 					getGNB();
# 				}catch(ex){
#
# 				}
# 				new naver.comic.RealtimeRankLayer();
# 				if ( $("uploadLinkId") ){
# 					$Fn(function(oEvent) {
# 						oEvent.stop();
# 						if ("true" != "false") {
# 							if (!confirm('로그인해야 이용할 수 있습니다. 로그인 하겠습니까?'))
# 								return false;
# 							else {
# 								location.href = "https://nid.naver.com/nidlogin.login?mode=form&url="
# 										+ encodeURIComponent("https://" + location.host
# 												+ "/upload/upload");
# 								return;
# 							}
# 						}
# 						location.href = "/upload/upload";
# 						return true;
# 					}).attach($("uploadLinkId"),"click");
# 				}
# 				naver.comic.oArtistAction = new naver.comic.Artist();
# 				artistAction = naver.comic.oArtistAction;
# 				naver.comic.oSearchBar = new naver.comic.SearchBarOptionActHandler();
#
# 				// GNB 이벤트 재정의.
# 				$Fn(function(oEvent){
# 					var aWtChild = $Element("gnb" ).child(function (v){return true;});
# 					var wtSrc = $Element(oEvent.element);
# 					var bContain = false;
# 					for (var i = 0 ; i < aWtChild.length ;i++){
# 						if ( aWtChild[i].$value() == wtSrc.$value()){
# 							bContain = true;
# 							break;
# 						}
# 					}
# 					if ( !bContain && gnbAllLayerClose ){
# 						gnbAllLayerClose();
#
# 					}
#
# 				}).attach(document,"click");
# 			}
# 			$Fn(loadEvent).attach(window,'load');
# 		</script>
# <script src="/aggregate/javascript/release/lcslog_20220127144815.js" type="text/javascript"></script>
# <script type="text/javascript">
#     try {
#         var eventType = "onpageshow" in window ? "onpageshow" : "onload";
#         var oldEvent = window[eventType];
#         window[eventType] = function() {
#             if (oldEvent) {
#                 oldEvent();
#             }
#             lcs_do();
#         };
#     } catch(ex) { }
# </script>
# </body>
# </html>

# %%
import requests
from bs4 import BeautifulSoup

main_url = 'https://comic.naver.com/webtoon/detail?titleId=748105&no=145&weekday=thu'
res = requests.get(main_url)

if res.ok:
    soup = BeautifulSoup(res.text, 'html.parser')
    img_tags = soup.select("img[src$='.jpg']")
    # print(len(img_tags), type(img_tags))
    # print(len(soup.select("img")))
    # print(len(soup.select("img[src$='.jpg']")))

    img_url_list = []
    for img_tag in img_tags:
        # print(type(img_tag), img_tag)
        img_url = img_tag['src']
        # print(img_url)
        img_url_list.append(img_url)

print(len(img_url_list))
print(img_url_list[:4])
# Out:
# 22
# ['https://shared-comic.pstatic.net/thumb/webtoon/748105/thumbnail/thumbnail_IMAG04_2b479f04-a16b-4fa2-9a05-bc60cd84022c.jpg', 'https://image-comic.pstatic.net/webtoon/748105/145/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_1.jpg', 'https://image-comic.pstatic.net/webtoon/748105/145/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_2.jpg', 'https://image-comic.pstatic.net/webtoon/748105/145/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_3.jpg']

# %%
# img 디렉토리 생성하기
import os

dir_path = 'img'

# img 디렉토리가 없으면
if not os.path.isdir(dir_path):
    os.mkdir(dir_path)

# %% [markdown]
# ### 디렉토리 생성하는 2가지 함수
# * os.mkdir() / osk.makedirs()
#   1. os.mkdir() 은 1개 폴더만 생성
#   2. os.makedirs() 는 a/b/c 처럼 하위 폴더를 생성

# %% [markdown]
# * 리스트를 순회하면서 image 다운로드 하기

# %%
for idx, img_url in enumerate(img_url_list, 1):
    print(f'다운로드 번호{idx} URL = {img_url}')
    req_header = {'referer':main_url}
    res = requests.get(img_url, headers=req_header)
    if res.ok:
        img_data = res.content
        file_name = os.path.basename(img_url)
        file_name = 'img/' + file_name
        with open(file_name, 'wb') as file:
            file.write(img_data)
# Out:
# 다운로드 번호1 URL = https://shared-comic.pstatic.net/thumb/webtoon/748105/thumbnail/thumbnail_IMAG04_2b479f04-a16b-4fa2-9a05-bc60cd84022c.jpg
# 다운로드 번호2 URL = https://image-comic.pstatic.net/webtoon/748105/145/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_1.jpg
# 다운로드 번호3 URL = https://image-comic.pstatic.net/webtoon/748105/145/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_2.jpg
# 다운로드 번호4 URL = https://image-comic.pstatic.net/webtoon/748105/145/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_3.jpg
# 다운로드 번호5 URL = https://image-comic.pstatic.net/webtoon/748105/145/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_4.jpg
# 다운로드 번호6 URL = https://image-comic.pstatic.net/webtoon/748105/145/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_5.jpg
# 다운로드 번호7 URL = https://image-comic.pstatic.net/webtoon/748105/145/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_6.jpg
# 다운로드 번호8 URL = https://image-comic.pstatic.net/webtoon/748105/145/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_7.jpg
# 다운로드 번호9 URL = https://image-comic.pstatic.net/webtoon/748105/145/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_8.jpg
# 다운로드 번호10 URL = https://image-comic.pstatic.net/webtoon/748105/145/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_9.jpg
# 다운로드 번호11 URL = https://image-comic.pstatic.net/webtoon/748105/145/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_10.jpg
# 다운로드 번호12 URL = https://image-comic.pstatic.net/webtoon/748105/145/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_11.jpg
# 다운로드 번호13 URL = https://image-comic.pstatic.net/webtoon/748105/145/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_12.jpg
# 다운로드 번호14 URL = https://image-comic.pstatic.net/webtoon/748105/145/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_13.jpg
# 다운로드 번호15 URL = https://image-comic.pstatic.net/webtoon/748105/145/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_14.jpg
# 다운로드 번호16 URL = https://image-comic.pstatic.net/webtoon/748105/145/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_15.jpg
# 다운로드 번호17 URL = https://image-comic.pstatic.net/webtoon/748105/145/20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_16.jpg
# 다운로드 번호18 URL = https://image-comic.pstatic.net/banner/store/banner_b788ef9e-8faa-41d7-8668-229d05d3b636.jpg
# 다운로드 번호19 URL = https://shared-comic.pstatic.net/thumb/webtoon/748105/142/thumbnail_202x120_0b8733fd-f346-4819-93db-9501c5b36d95.jpg
# 다운로드 번호20 URL = https://shared-comic.pstatic.net/thumb/webtoon/748105/143/thumbnail_202x120_b3ebf09a-c025-423e-8dfe-852b00f91616.jpg
# 다운로드 번호21 URL = https://shared-comic.pstatic.net/thumb/webtoon/748105/144/thumbnail_202x120_60e88c76-8eab-488b-8e85-5f8a98cee8f3.jpg
# 다운로드 번호22 URL = https://shared-comic.pstatic.net/thumb/webtoon/748105/145/thumbnail_202x120_0d81306a-5cc2-40cc-95b7-26960d56af21.jpg

# %%
# 파일들이 있는 디렉토리 삭제
import shutil
import os

dir_path = 'img'
# img 디렉토리가 있다면
if os.path.exists(dir_path):
    shutil.rmtree(dir_path)

# %% [markdown]
# * 웹툰의 타이틀과 특정회차 url을 아규먼트로 받아서 다운로드 하는 함수 구현하기

# %%
def download_image(title, round_url):
    import requests
    from bs4 import BeautifulSoup
    import os
    import shutil

    # img 풀더가 있으면 삭제하기
    dir_path = 'img'
    if os.path.exists(dir_path):
        shutil.rmtree(dir_path)

    # img 디렉토리가 없으면
    if not os.path.isdir(dir_path):
        title_path = os.path.join(dir_path, title)
        print(title_path)
        os.makedirs(title_path)

    # img url 목록을 알아냐기 위한 요청을 보내기
    res = requests.get(round_url)
    if res.ok:
        # 응답으로 받은 html 텍스트를 파싱하기 위한 파서(BeautifulSoup) 객체 생성
        soup = BeautifulSoup(res.text, 'html.parser')
        # img태그 중에서 src 속성의 값이 ".jpg"로 끝나는 태그들만 선택하기
        img_tags = soup.select("img[src$='.jpg']")
        # print(len(img_tags), type(img_tags))
        # print(len(soup.select("img")))
        # print(len(soup.select("img[src$='.jpg']")))

        # 특정회차 url을 referer 헤더로 설정하기
        req_header = {'referer' : round_url}

        for idx, img_tag in enumerate(img_tags, 1):
            # img 태그의 src 속성의 값을 추출하기
            print(f'------> 다운로드 번호 {idx}')
            img_url = img_tag['src']

            # jpg image 데이터 요청하기
            res_img = requests.get(img_url, headers=req_header)
            if res_img.ok:
                # image binary 데이터 가져오기
                img_data = res_img.content

                # img\독립일기\thumbnail_IMAG04_2b479f04-a16b-4fa2-9a05-bc60cd84022c.jpg
                file_name = title_path + '\\' + os.path.basename(img_url)

                with open(file_name, 'wb') as file:
                    print(f'{file_name}({len(img_data)}) bytes')
                    file.write(img_data)

# %%
download_image('독립일기','https://comic.naver.com/webtoon/detail?titleId=748105&no=145&weekday=thu')
# Out:
# img\독립일기
# ------> 다운로드 번호 1
# img\독립일기\thumbnail_IMAG04_2b479f04-a16b-4fa2-9a05-bc60cd84022c.jpg(15357) bytes
# ------> 다운로드 번호 2
# img\독립일기\20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_1.jpg(115541) bytes
# ------> 다운로드 번호 3
# img\독립일기\20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_2.jpg(117154) bytes
# ------> 다운로드 번호 4
# img\독립일기\20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_3.jpg(139410) bytes
# ------> 다운로드 번호 5
# img\독립일기\20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_4.jpg(137058) bytes
# ------> 다운로드 번호 6
# img\독립일기\20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_5.jpg(156686) bytes
# ------> 다운로드 번호 7
# img\독립일기\20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_6.jpg(145753) bytes
# ------> 다운로드 번호 8
# img\독립일기\20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_7.jpg(185411) bytes
# ------> 다운로드 번호 9
# img\독립일기\20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_8.jpg(156712) bytes
# ------> 다운로드 번호 10
# img\독립일기\20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_9.jpg(157234) bytes
# ------> 다운로드 번호 11
# img\독립일기\20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_10.jpg(148701) bytes
# ------> 다운로드 번호 12
# img\독립일기\20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_11.jpg(118678) bytes
# ------> 다운로드 번호 13
# img\독립일기\20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_12.jpg(145830) bytes
# ------> 다운로드 번호 14
# img\독립일기\20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_13.jpg(50275) bytes
# ------> 다운로드 번호 15
# img\독립일기\20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_14.jpg(150569) bytes
# ------> 다운로드 번호 16
# img\독립일기\20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_15.jpg(174820) bytes
# ------> 다운로드 번호 17
# img\독립일기\20220126180009_7606331a182af3f83de682399ffcc311_IMAG01_16.jpg(87977) bytes
# ------> 다운로드 번호 18
# img\독립일기\banner_b788ef9e-8faa-41d7-8668-229d05d3b636.jpg(30980) bytes
# ------> 다운로드 번호 19
# img\독립일기\thumbnail_202x120_0b8733fd-f346-4819-93db-9501c5b36d95.jpg(13449) bytes
# ------> 다운로드 번호 20
# img\독립일기\thumbnail_202x120_b3ebf09a-c025-423e-8dfe-852b00f91616.jpg(21009) bytes
# ------> 다운로드 번호 21
# img\독립일기\thumbnail_202x120_60e88c76-8eab-488b-8e85-5f8a98cee8f3.jpg(27661) bytes
# ------> 다운로드 번호 22
# img\독립일기\thumbnail_202x120_0d81306a-5cc2-40cc-95b7-26960d56af21.jpg(26367) bytes

# %% [markdown]
# ### Image File Upload
# * https://httpbin.org/post URL로 요청을 보내서 다운로드 받은 img 파일을 업로드 하기
# * requests.post() 함수를 사용하고, files 속성에 image data를 지정한다.
# * files - (optional) Dictionary of 'filename' : file-objects for multipart encoding upload.

# %%
import requests

upload_file_dict = {
    'img1' : open('data\\f1.jpg', 'rb'),
    'img2' : open('data\\f2.jpg', 'rb'),
    'img3' : open('data\\f3.jpg', 'rb')
}

url = 'https://httpbin.org/post'
res = requests.post(url, files=upload_file_dict)
print(res.status_code)
res_data = res.json()
img1_data = res_data['files']['img1']
print(img1_data)
# Out:
# 200
# data:application/octet-stream;base64,...
