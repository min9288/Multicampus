# %%
# !pip install pillow

# %%
# !pip install numpy

# %%
from PIL import Image
# 이미지 열기
tmp = Image.open('./picture/pic1.jpg')

# 이미지 크기 출력
print(tmp.size)
tmp
# Out:
# (740, 4000)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=740x4000 at 0x25B0139FE20>

# %%
import numpy as np
np

# %%
fileName='pic1'
tmp=Image.open('./picture/' + fileName + '.jpg')

tmpResize=tmp.resize((200,200))
tmpResize.save('./picture/200' + fileName + '.jpg')

print('---end ---')
# Out:
# ---end ---

# %%
fileName='pic1'
tmp=Image.open('./picture/' + fileName + '.jpg')

size=300
tmpResize=tmp.resize((size,size))
tmpResize.save('./picture/' + str(size) + fileName + '.jpg')

print('---end ---')
# Out:
# ---end ---

# %%
image1 = Image.open('./picture/pic3.jpg')
image1.show()
# 이미지 좌우대칭
FlipImage = image1.transpose(Image.ROTATE_90)
FlipImage.show()

# %%
image1 = Image.open('./picture/pic3.jpg')
image1.show()
# 이미지 좌우대칭
FlipImage2 = image1.convert("L")
FlipImage2.show()
